# %% [markdown]
# # **Step 1: Stock Price Analysis and Prediction**

# %% [markdown]
# ## Importing Required Libraries for numerical analysis and prediction of stock prices
#
# Technical Stack used :
# * Numpy Array
# * Matplotlib
# * Pandas
# * Keras
# * Scikit Learn
# * Math

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn import metrics 
from keras.models import Sequential
from keras.layers import Dense, LSTM
import math

# %% [markdown]
# ## Importing the Numerical dataset and performing Exploratory Analysis

# %%
# Dataframe for exploratory analysis
df=pd.read_csv('/Users/mahir/Downloads/Stock_Prediction_using_Numerical_and_Sentiment_Analysis/TCS.NS_Stock.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close
# 0  01-01-2003  59.987499  61.974998  59.987499  61.087502  45.521038  \
# 1  02-01-2003  61.525002  62.924999  57.912498  58.299999  43.443855
# 2  03-01-2003  60.000000  61.049999  58.500000  59.012501  43.974789
# 3  06-01-2003  59.924999  60.187500  56.875000  57.262501  42.670746
# 4  07-01-2003  58.000000  58.500000  56.062500  56.599998  42.177040
#
#       Volume
# 0  6027072.0
# 1  5325328.0
# 2  4198040.0
# 3  4121520.0
# 4  2650800.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4476 entries, 0 to 4475
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4476 non-null   object
#  1   Open       4460 non-null   float64
#  2   High       4460 non-null   float64
#  3   Low        4460 non-null   float64
#  4   Close      4460 non-null   float64
#  5   Adj Close  4460 non-null   float64
#  6   Volume     4460 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 244.9+ KB

# %%
# Extract date frame and plot closing stock price w.r.t time
df['Date'] = pd.to_datetime(df.Date,format='%d-%m-%Y')
df.index = df['Date']
df.dropna(inplace=True)
#plot
plt.figure(figsize=(16,8))
plt.title('Close Price history\n')
plt.xlabel('Time (Year)')
plt.ylabel('Close Price')
plt.plot(df['Close'])

# %%
# fix random seed for reproducibility
np.random.seed(7)

# %% [markdown]
# ## Creating a dataframe for storing the closing stock data per day

# %%
# convert an array of values into a dataset matrix
def create_dataset(df2, look_back=1):
	dataX, dataY = [], []
	for i in range(len(df2)-look_back-1):
		a = df2[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(df2[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
df2 = pd.read_csv('/Users/mahir/Downloads/Stock_Prediction_using_Numerical_and_Sdntiment_Analysis/TCS.NS_Stock.csv', usecols=[5], engine='python')
df2.dropna(inplace=True)
df2 = df2.values
df2 = df2.astype('float32')

# %% [markdown]
# ## Data Normalization and Division into Training and Test sets

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
df2 = scaler.fit_transform(df2)

# split into train and test sets
train_size = int(len(df2) * 0.67)
test_size = len(df2) - train_size
train, test = df2[0:train_size,:], df2[train_size:len(df2),:]

# %%
# reshape into X=t and Y=t+1
look_back = 2
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %% [markdown]
# ## Creating a LSTM Neural Network Model for Numerical Analysis

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(7, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=5, verbose=2)
# Out:
# Epoch 1/100
# 597/597 - 2s - loss: 0.0049 - 2s/epoch - 3ms/step
# Epoch 2/100
# 597/597 - 1s - loss: 1.8942e-05 - 525ms/epoch - 880us/step
# Epoch 3/100
# 597/597 - 1s - loss: 1.6086e-05 - 527ms/epoch - 883us/step
# Epoch 4/100
# 597/597 - 1s - loss: 1.4300e-05 - 503ms/epoch - 842us/step
# Epoch 5/100
# 597/597 - 1s - loss: 1.3117e-05 - 509ms/epoch - 852us/step
# Epoch 6/100
# 597/597 - 1s - loss: 1.3339e-05 - 512ms/epoch - 857us/step
# Epoch 7/100
# 597/597 - 1s - loss: 1.2932e-05 - 518ms/epoch - 867us/step
# Epoch 8/100
# 597/597 - 0s - loss: 1.2804e-05 - 499ms/epoch - 836us/step
# Epoch 9/100
# 597/597 - 1s - loss: 1.3082e-05 - 512ms/epoch - 858us/step
# Epoch 10/100
# 597/597 - 1s - loss: 1.3894e-05 - 531ms/epoch - 889us/step
# Epoch 11/100
# 597/597 - 1s - loss: 1.3548e-05 - 555ms/epoch - 929us/step
# Epoch 12/100
# 597/597 - 1s - loss: 1.3021e-05 - 552ms/epoch - 924us/step
# Epoch 13/100
# 597/597 - 1s - loss: 1.4060e-05 - 562ms/epoch - 941us/step
# Epoch 14/100
# 597/597 - 1s - loss: 1.4800e-05 - 521ms/epoch - 872us/step
# Epoch 15/100
# 597/597 - 1s - loss: 1.3770e-05 - 513ms/epoch - 860us/step
# Epoch 16/100
# 597/597 - 1s - loss: 1.3458e-05 - 561ms/epoch - 940us/step
# Epoch 17/100
# 597/597 - 1s - loss: 1.3393e-05 - 539ms/epoch - 902us/step
# Epoch 18/100
# 597/597 - 1s - loss: 1.3986e-05 - 560ms/epoch - 938us/step
# Epoch 19/100
# 597/597 - 1s - loss: 1.3352e-05 - 537ms/epoch - 900us/step
# Epoch 20/100
# 597/597 - 1s - loss: 1.3311e-05 - 513ms/epoch - 859us/step
# Epoch 21/100
# 597/597 - 1s - loss: 1.2966e-05 - 509ms/epoch - 853us/step
# Epoch 22/100
# 597/597 - 1s - loss: 1.3111e-05 - 522ms/epoch - 874us/step
# Epoch 23/100
# 597/597 - 1s - loss: 1.3630e-05 - 502ms/epoch - 841us/step
# Epoch 24/100
# 597/597 - 1s - loss: 1.3002e-05 - 504ms/epoch - 844us/step
# Epoch 25/100
# 597/597 - 1s - loss: 1.3441e-05 - 507ms/epoch - 849us/step
# Epoch 26/100
# 597/597 - 1s - loss: 1.2562e-05 - 510ms/epoch - 854us/step
# Epoch 27/100
# 597/597 - 1s - loss: 1.3158e-05 - 502ms/epoch - 841us/step
# Epoch 28/100
# 597/597 - 1s - loss: 1.3226e-05 - 509ms/epoch - 853us/step
# Epoch 29/100
# 597/597 - 1s - loss: 1.3052e-05 - 510ms/epoch - 854us/step
# Epoch 30/100
# 597/597 - 1s - loss: 1.2843e-05 - 511ms/epoch - 856us/step
# Epoch 31/100
# 597/597 - 1s - loss: 1.2430e-05 - 504ms/epoch - 843us/step
# Epoch 32/100
# 597/597 - 1s - loss: 1.3310e-05 - 505ms/epoch - 846us/step
# Epoch 33/100
# 597/597 - 1s - loss: 1.3092e-05 - 501ms/epoch - 839us/step
# Epoch 34/100
# 597/597 - 1s - loss: 1.2568e-05 - 503ms/epoch - 843us/step
# Epoch 35/100
# 597/597 - 1s - loss: 1.2800e-05 - 523ms/epoch - 876us/step
# Epoch 36/100
# 597/597 - 1s - loss: 1.2690e-05 - 509ms/epoch - 852us/step
# Epoch 37/100
# 597/597 - 1s - loss: 1.2702e-05 - 502ms/epoch - 842us/step
# Epoch 38/100
# 597/597 - 1s - loss: 1.2592e-05 - 504ms/epoch - 845us/step
# Epoch 39/100
# 597/597 - 1s - loss: 1.2217e-05 - 553ms/epoch - 926us/step
# Epoch 40/100
# 597/597 - 1s - loss: 1.2948e-05 - 530ms/epoch - 887us/step
# Epoch 41/100
# 597/597 - 1s - loss: 1.1868e-05 - 562ms/epoch - 941us/step
# Epoch 42/100
# 597/597 - 1s - loss: 1.2975e-05 - 538ms/epoch - 901us/step
# Epoch 43/100
# 597/597 - 1s - loss: 1.2813e-05 - 554ms/epoch - 929us/step
# Epoch 44/100
# 597/597 - 1s - loss: 1.2478e-05 - 544ms/epoch - 911us/step
# Epoch 45/100
# 597/597 - 1s - loss: 1.2334e-05 - 511ms/epoch - 856us/step
# Epoch 46/100
# 597/597 - 1s - loss: 1.3054e-05 - 509ms/epoch - 852us/step
# Epoch 47/100
# 597/597 - 1s - loss: 1.2079e-05 - 512ms/epoch - 858us/step
# Epoch 48/100
# 597/597 - 1s - loss: 1.2976e-05 - 505ms/epoch - 845us/step
# Epoch 49/100
# 597/597 - 1s - loss: 1.1336e-05 - 503ms/epoch - 842us/step
# Epoch 50/100
# 597/597 - 1s - loss: 1.1589e-05 - 550ms/epoch - 921us/step
# Epoch 51/100
# 597/597 - 1s - loss: 1.3070e-05 - 535ms/epoch - 896us/step
# Epoch 52/100
# 597/597 - 1s - loss: 1.2273e-05 - 527ms/epoch - 883us/step
# Epoch 53/100
# 597/597 - 1s - loss: 1.1557e-05 - 534ms/epoch - 894us/step
# Epoch 54/100
# 597/597 - 1s - loss: 1.1439e-05 - 544ms/epoch - 911us/step
# Epoch 55/100
# 597/597 - 1s - loss: 1.1715e-05 - 545ms/epoch - 913us/step
# Epoch 56/100
# 597/597 - 1s - loss: 1.3017e-05 - 517ms/epoch - 865us/step
# Epoch 57/100
# 597/597 - 1s - loss: 1.1733e-05 - 533ms/epoch - 892us/step
# Epoch 58/100
# 597/597 - 1s - loss: 1.1189e-05 - 544ms/epoch - 911us/step
# Epoch 59/100
# 597/597 - 1s - loss: 1.1229e-05 - 544ms/epoch - 911us/step
# Epoch 60/100
# 597/597 - 1s - loss: 1.1159e-05 - 538ms/epoch - 901us/step
# Epoch 61/100
# 597/597 - 1s - loss: 1.1102e-05 - 507ms/epoch - 850us/step
# Epoch 62/100
# 597/597 - 1s - loss: 1.0711e-05 - 506ms/epoch - 847us/step
# Epoch 63/100
# 597/597 - 1s - loss: 1.1122e-05 - 521ms/epoch - 873us/step
# Epoch 64/100
# 597/597 - 1s - loss: 1.1715e-05 - 532ms/epoch - 890us/step
# Epoch 65/100
# 597/597 - 1s - loss: 1.1336e-05 - 523ms/epoch - 876us/step
# Epoch 66/100
# 597/597 - 1s - loss: 1.0428e-05 - 528ms/epoch - 884us/step
# Epoch 67/100
# 597/597 - 1s - loss: 1.1029e-05 - 569ms/epoch - 952us/step
# Epoch 68/100
# 597/597 - 1s - loss: 1.0439e-05 - 534ms/epoch - 895us/step
# Epoch 69/100
# 597/597 - 1s - loss: 1.0956e-05 - 560ms/epoch - 938us/step
# Epoch 70/100
# 597/597 - 1s - loss: 1.0502e-05 - 509ms/epoch - 853us/step
# Epoch 71/100
# 597/597 - 1s - loss: 1.1426e-05 - 578ms/epoch - 968us/step
# Epoch 72/100
# 597/597 - 1s - loss: 1.0593e-05 - 566ms/epoch - 947us/step
# Epoch 73/100
# 597/597 - 1s - loss: 1.0446e-05 - 573ms/epoch - 960us/step
# Epoch 74/100
# 597/597 - 1s - loss: 1.0633e-05 - 567ms/epoch - 950us/step
# Epoch 75/100
# 597/597 - 1s - loss: 1.0560e-05 - 535ms/epoch - 896us/step
# Epoch 76/100
# 597/597 - 1s - loss: 1.0827e-05 - 513ms/epoch - 859us/step
# Epoch 77/100
# 597/597 - 1s - loss: 1.1112e-05 - 515ms/epoch - 863us/step
# Epoch 78/100
# 597/597 - 1s - loss: 1.0650e-05 - 526ms/epoch - 881us/step
# Epoch 79/100
# 597/597 - 1s - loss: 1.0978e-05 - 508ms/epoch - 851us/step
# Epoch 80/100
# 597/597 - 1s - loss: 1.1221e-05 - 517ms/epoch - 865us/step
# Epoch 81/100
# 597/597 - 1s - loss: 1.0705e-05 - 520ms/epoch - 870us/step
# Epoch 82/100
# 597/597 - 1s - loss: 1.0323e-05 - 506ms/epoch - 848us/step
# Epoch 83/100
# 597/597 - 1s - loss: 1.0526e-05 - 510ms/epoch - 854us/step
# Epoch 84/100
# 597/597 - 1s - loss: 1.0927e-05 - 500ms/epoch - 838us/step
# Epoch 85/100
# 597/597 - 1s - loss: 1.1073e-05 - 504ms/epoch - 845us/step
# Epoch 86/100
# 597/597 - 1s - loss: 1.0619e-05 - 519ms/epoch - 869us/step
# Epoch 87/100
# 597/597 - 1s - loss: 1.0336e-05 - 531ms/epoch - 889us/step
# Epoch 88/100
# 597/597 - 1s - loss: 1.0181e-05 - 505ms/epoch - 846us/step
# Epoch 89/100
# 597/597 - 1s - loss: 1.1194e-05 - 521ms/epoch - 873us/step
# Epoch 90/100
# 597/597 - 1s - loss: 1.0442e-05 - 511ms/epoch - 855us/step
# Epoch 91/100
# 597/597 - 1s - loss: 1.0058e-05 - 503ms/epoch - 843us/step
# Epoch 92/100
# 597/597 - 1s - loss: 1.0437e-05 - 505ms/epoch - 845us/step
# Epoch 93/100
# 597/597 - 1s - loss: 1.0286e-05 - 504ms/epoch - 845us/step
# Epoch 94/100
# 597/597 - 1s - loss: 1.0486e-05 - 502ms/epoch - 841us/step
# Epoch 95/100
# 597/597 - 1s - loss: 1.1510e-05 - 510ms/epoch - 854us/step
# Epoch 96/100
# 597/597 - 1s - loss: 1.0305e-05 - 514ms/epoch - 861us/step
# Epoch 97/100
# 597/597 - 1s - loss: 1.0333e-05 - 523ms/epoch - 876us/step
# Epoch 98/100
# 597/597 - 1s - loss: 1.0190e-05 - 510ms/epoch - 854us/step
# Epoch 99/100
# 597/597 - 1s - loss: 1.0330e-05 - 511ms/epoch - 856us/step
# Epoch 100/100
# 597/597 - 1s - loss: 9.7664e-06 - 515ms/epoch - 862us/step

# %% [markdown]
# ## Making Predictions of the Model

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# Out:
# 94/94 [==============================] - 0s 719us/step
# 46/46 [==============================] - 0s 746us/step

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(df2)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(df2)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(df2)-1, :] = testPredict
df['Date'] = pd.to_datetime(df.Date,format='%d-%m-%Y')
df.index = df['Date']
df.dropna(inplace=True)
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df2), label = 'Actual Data')
plt.title('TCS Stock Price Prediction from 17 years Data')
plt.xlabel('Time(Year)')
plt.ylabel('Actual Stock Price')
plt.plot(trainPredictPlot,color='#DE3163', label = 'Train Predicted Data')
plt.plot(testPredictPlot, color='#FFC300', label = 'Test Predicted Data')
plt.legend(loc='best')
plt.show()

# %%
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print("Root mean square error of Training  = ",trainScore," RMSE")
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print("Root mean square error of Testing = ",testScore," RMSE")
# Out:
# Root mean square error of Training  =  10.131590332683816  RMSE
# Root mean square error of Testing =  58.656166352551764  RMSE

# %% [markdown]
# # **Step 2: Textual Data(News Headlines) Analysis**

# %% [markdown]
# ## Importing Required Libraries for Textual (News Headlines) analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from textblob import TextBlob
from datetime import datetime

# %% [markdown]
# ## Importing the textual dataset and performing Exploratory Analysis

# %%
data = pd.read_csv('/Users/mahir/Downloads/Stock_Prediction_using_Numerical_and_Sentiment_Analysis/india-news-headlines.csv')
data.head()
# Out:
#    publish_date headline_category
# 0      20010102           unknown  \
# 1      20010102           unknown
# 2      20010102           unknown
# 3      20010102           unknown
# 4      20010102           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %%
data['publish_date'].duplicated()
# Out:
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 3650965     True
# 3650966     True
# 3650967     True
# 3650968     True
# 3650969     True
# Name: publish_date, Length: 3650970, dtype: bool

# %%
data = data.drop_duplicates('publish_date', keep='first').sort_index()
data= data.reset_index()

# %%
data.rename(columns={'publish_date': 'Date'},inplace = True)
data.head()
# Out:
#    index      Date headline_category
# 0      0  20010102           unknown  \
# 1     86  20010103           unknown
# 2    127  20010104           unknown
# 3    280  20010105           unknown
# 4    406  20010106           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1           Powerless north India gropes in the dark
# 2    The string that pulled Stephen Hawking to India
# 3     Light combat craft takes India into club class
# 4     Light combat craft takes India into club class

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7717 entries, 0 to 7716
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              7717 non-null   int64
#  1   Date               7717 non-null   int64
#  2   headline_category  7717 non-null   object
#  3   headline_text      7717 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 241.3+ KB

# %% [markdown]
# ## Sentiment Analysis of News Headlines

# %%
def getAnalysis_polarity(headline):
    result = TextBlob(headline)
    
    if result.sentiment.polarity < 0:
        return 'negative'
    elif result.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'positive'

# %%
data['Result'] = np.array([getAnalysis_polarity(headline) for headline in data['headline_text']])

# %%
final_result = data.groupby(['Result']).agg({'headline_text':'count'})
final_result
# Out:
#           headline_text
# Result
# negative            773
# neutral            5113
# positive           1831

# %%
negative = (final_result.loc['negative'] / len(data))*100
neutral = (final_result.loc['neutral'] / len(data))*100
positive = (final_result.loc['positive'] / len(data))*100


print('Positive Headlines: ' , positive )
print('\n\nNegative Headlines: ' ,negative )
print('\n\nUnbiased Headlines: ' , str(neutral))
# Out:
# Positive Headlines:  headline_text    23.726837
# Name: positive, dtype: float64
#
#
# Negative Headlines:  headline_text    10.016846
# Name: negative, dtype: float64
#
#
# Unbiased Headlines:  headline_text    66.256317
# Name: neutral, dtype: float64

# %%
plt.figure(figsize=(8,8))
final_result['headline_text'].plot.pie(autopct='%1.1f%%')
plt.title("Overall Sentiment Distribution Pie Chart",fontweight="bold")
plt.show()

# %% [markdown]
# # Step 3: Creating Hybrid model for stock price/performance prediction using numerical analysis of historical stock prices, and sentimental analysis of news headlines

# %% [markdown]
# ## Importing Required Libraries

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ------------------------------------ 126.0/126.0 kB 570.0 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\mahir\anaconda3\lib\site-packages (from vaderSentiment) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mahir\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mahir\anaconda3\lib\site-packages (from requests->vaderSentiment) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mahir\anaconda3\lib\site-packages (from requests->vaderSentiment) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mahir\anaconda3\lib\site-packages (from requests->vaderSentiment) (2022.12.7)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import re
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# ## Importing the numerical and textual dataset

# %%
stock_data=pd.read_csv('/Users/mahir/Downloads/Stock_Prediction_using_Numerical_and_Sentiment_Analysis/TCS.NS_Stock.csv')
stock_data.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close
# 0  01-01-2003  59.987499  61.974998  59.987499  61.087502  45.521038  \
# 1  02-01-2003  61.525002  62.924999  57.912498  58.299999  43.443855
# 2  03-01-2003  60.000000  61.049999  58.500000  59.012501  43.974789
# 3  06-01-2003  59.924999  60.187500  56.875000  57.262501  42.670746
# 4  07-01-2003  58.000000  58.500000  56.062500  56.599998  42.177040
#
#       Volume
# 0  6027072.0
# 1  5325328.0
# 2  4198040.0
# 3  4121520.0
# 4  2650800.0

# %%
news_data=pd.read_csv('/Users/mahir/Downloads/Stock_Prediction_using_Numerical_and_Sentiment_Analysis/india-news-headlines.csv')
news_data.head()
# Out:
#    publish_date headline_category
# 0      20010102           unknown  \
# 1      20010102           unknown
# 2      20010102           unknown
# 3      20010102           unknown
# 4      20010102           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %%
news_data.rename(columns={'publish_date': 'Date'},inplace = True)
news_data.head()
# Out:
#        Date headline_category
# 0  20010102           unknown  \
# 1  20010102           unknown
# 2  20010102           unknown
# 3  20010102           unknown
# 4  20010102           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %% [markdown]
# ## Creating Hybrid data from Numerical and Textual Data

# %%
hybrid_data = pd.merge(stock_data,news_data, 
                   how ='inner',
                   left_index = True,
                   right_index = True)

# %%
hybrid_data.head()
# Out:
#        Date_x       Open       High        Low      Close  Adj Close
# 0  01-01-2003  59.987499  61.974998  59.987499  61.087502  45.521038  \
# 1  02-01-2003  61.525002  62.924999  57.912498  58.299999  43.443855
# 2  03-01-2003  60.000000  61.049999  58.500000  59.012501  43.974789
# 3  06-01-2003  59.924999  60.187500  56.875000  57.262501  42.670746
# 4  07-01-2003  58.000000  58.500000  56.062500  56.599998  42.177040
#
#       Volume    Date_y headline_category
# 0  6027072.0  20010102           unknown  \
# 1  5325328.0  20010102           unknown
# 2  4198040.0  20010102           unknown
# 3  4121520.0  20010102           unknown
# 4  2650800.0  20010102           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %% [markdown]
# ## Performing Sentiment Analysis on Hybrid Data

# %% [markdown]
# ## Sentiment Analysis using TextBlob

# %%
def analysis_polarity(headline):
    result = TextBlob(headline)
    
    if result.sentiment.polarity < 0:
        return 'negative'
    elif result.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'positive'

# %%
hybrid_data['sentiment'] = np.array([analysis_polarity(headline) for headline in hybrid_data['headline_text']])
hybrid_data.head()
# Out:
#        Date_x       Open       High        Low      Close  Adj Close
# 0  01-01-2003  59.987499  61.974998  59.987499  61.087502  45.521038  \
# 1  02-01-2003  61.525002  62.924999  57.912498  58.299999  43.443855
# 2  03-01-2003  60.000000  61.049999  58.500000  59.012501  43.974789
# 3  06-01-2003  59.924999  60.187500  56.875000  57.262501  42.670746
# 4  07-01-2003  58.000000  58.500000  56.062500  56.599998  42.177040
#
#       Volume    Date_y headline_category
# 0  6027072.0  20010102           unknown  \
# 1  5325328.0  20010102           unknown
# 2  4198040.0  20010102           unknown
# 3  4121520.0  20010102           unknown
# 4  2650800.0  20010102           unknown
#
#                                        headline_text sentiment
# 0  Status quo will not be disturbed at Ayodhya; s...   neutral
# 1                Fissures in Hurriyat over Pak visit   neutral
# 2              America's unwanted heading for India?   neutral
# 3                 For bigwigs; it is destination Goa   neutral
# 4               Extra buses to clear tourist traffic  positive

# %%
senti_data = pd.get_dummies(hybrid_data['sentiment'],drop_first=True)

# %%
hybrid_data = pd.concat([hybrid_data,senti_data],axis=1)

# %%
hybrid_data.head()
# Out:
#        Date_x       Open       High        Low      Close  Adj Close
# 0  01-01-2003  59.987499  61.974998  59.987499  61.087502  45.521038  \
# 1  02-01-2003  61.525002  62.924999  57.912498  58.299999  43.443855
# 2  03-01-2003  60.000000  61.049999  58.500000  59.012501  43.974789
# 3  06-01-2003  59.924999  60.187500  56.875000  57.262501  42.670746
# 4  07-01-2003  58.000000  58.500000  56.062500  56.599998  42.177040
#
#       Volume    Date_y headline_category
# 0  6027072.0  20010102           unknown  \
# 1  5325328.0  20010102           unknown
# 2  4198040.0  20010102           unknown
# 3  4121520.0  20010102           unknown
# 4  2650800.0  20010102           unknown
#
#                                        headline_text sentiment  neutral
# 0  Status quo will not be disturbed at Ayodhya; s...   neutral     True  \
# 1                Fissures in Hurriyat over Pak visit   neutral     True
# 2              America's unwanted heading for India?   neutral     True
# 3                 For bigwigs; it is destination Goa   neutral     True
# 4               Extra buses to clear tourist traffic  positive    False
#
#    positive
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True

# %% [markdown]
# ## Adding subjectivity and polarity scores to the news headlines

# %%
#Functions to get the subjectivity and polarity
def getSubjectivity(text):
  return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
  return  TextBlob(text).sentiment.polarity

# %%
#Adding subjectivity and polarity columns
hybrid_data['Subjectivity'] =hybrid_data['headline_text'].apply(getSubjectivity)
hybrid_data['Polarity'] = hybrid_data['headline_text'].apply(getPolarity)
hybrid_data.head()
# Out:
#        Date_x       Open       High        Low      Close  Adj Close
# 0  01-01-2003  59.987499  61.974998  59.987499  61.087502  45.521038  \
# 1  02-01-2003  61.525002  62.924999  57.912498  58.299999  43.443855
# 2  03-01-2003  60.000000  61.049999  58.500000  59.012501  43.974789
# 3  06-01-2003  59.924999  60.187500  56.875000  57.262501  42.670746
# 4  07-01-2003  58.000000  58.500000  56.062500  56.599998  42.177040
#
#       Volume    Date_y headline_category
# 0  6027072.0  20010102           unknown  \
# 1  5325328.0  20010102           unknown
# 2  4198040.0  20010102           unknown
# 3  4121520.0  20010102           unknown
# 4  2650800.0  20010102           unknown
#
#                                        headline_text sentiment  neutral
# 0  Status quo will not be disturbed at Ayodhya; s...   neutral     True  \
# 1                Fissures in Hurriyat over Pak visit   neutral     True
# 2              America's unwanted heading for India?   neutral     True
# 3                 For bigwigs; it is destination Goa   neutral     True
# 4               Extra buses to clear tourist traffic  positive    False
#
#    positive  Subjectivity  Polarity
# 0     False      0.000000      0.00
# 1     False      0.000000      0.00
# 2     False      0.000000      0.00
# 3     False      0.000000      0.00
# 4      True      0.241667      0.05

# %% [markdown]
# ## Performing Sentiment Analysis over the news Headlines of Hybrid Data

# %%
#Adding sentiment score to news
senti_int_an = SentimentIntensityAnalyzer()

hybrid_data['Compound'] = [senti_int_an.polarity_scores(v)['compound'] for v in hybrid_data['headline_text']]
hybrid_data['Negative'] = [senti_int_an.polarity_scores(v)['neg'] for v in hybrid_data['headline_text']]
hybrid_data['Neutral'] = [senti_int_an.polarity_scores(v)['neu'] for v in hybrid_data['headline_text']]
hybrid_data['Positive'] = [senti_int_an.polarity_scores(v)['pos'] for v in hybrid_data['headline_text']]
hybrid_data.head()
# Out:
#        Date_x       Open       High        Low      Close  Adj Close
# 0  01-01-2003  59.987499  61.974998  59.987499  61.087502  45.521038  \
# 1  02-01-2003  61.525002  62.924999  57.912498  58.299999  43.443855
# 2  03-01-2003  60.000000  61.049999  58.500000  59.012501  43.974789
# 3  06-01-2003  59.924999  60.187500  56.875000  57.262501  42.670746
# 4  07-01-2003  58.000000  58.500000  56.062500  56.599998  42.177040
#
#       Volume    Date_y headline_category
# 0  6027072.0  20010102           unknown  \
# 1  5325328.0  20010102           unknown
# 2  4198040.0  20010102           unknown
# 3  4121520.0  20010102           unknown
# 4  2650800.0  20010102           unknown
#
#                                        headline_text sentiment  neutral
# 0  Status quo will not be disturbed at Ayodhya; s...   neutral     True  \
# 1                Fissures in Hurriyat over Pak visit   neutral     True
# 2              America's unwanted heading for India?   neutral     True
# 3                 For bigwigs; it is destination Goa   neutral     True
# 4               Extra buses to clear tourist traffic  positive    False
#
#    positive  Subjectivity  Polarity  Compound  Negative  Neutral  Positive
# 0     False      0.000000      0.00    0.2924     0.000    0.805     0.195
# 1     False      0.000000      0.00    0.0000     0.000    1.000     0.000
# 2     False      0.000000      0.00   -0.2263     0.322    0.678     0.000
# 3     False      0.000000      0.00    0.0000     0.000    1.000     0.000
# 4      True      0.241667      0.05    0.3818     0.000    0.658     0.342

# %%
hybrid_data.columns
# Out:
# Index(['Date_x', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Date_y', 'headline_category', 'headline_text', 'sentiment', 'neutral',
#        'positive', 'Subjectivity', 'Polarity', 'Compound', 'Negative',
#        'Neutral', 'Positive'],
#       dtype='object')

# %%
req_col = [ 'Open',  'High', 'Low','Volume','Compound', 'Negative', 'Neutral' ,'Positive','positive']

# %%
new_hybrid = hybrid_data[req_col]
new_hybrid.reset_index(inplace = True)

# %%
new_hybrid.rename(columns = {'positive':'Label'}, inplace = True)
# Out:
# C:\Users\mahir\AppData\Local\Temp\ipykernel_341808\2165816261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_hybrid.rename(columns = {'positive':'Label'}, inplace = True)

# %%
new_hybrid.head()
# Out:
#    index       Open       High        Low     Volume  Compound  Negative
# 0      0  59.987499  61.974998  59.987499  6027072.0    0.2924     0.000  \
# 1      1  61.525002  62.924999  57.912498  5325328.0    0.0000     0.000
# 2      2  60.000000  61.049999  58.500000  4198040.0   -0.2263     0.322
# 3      3  59.924999  60.187500  56.875000  4121520.0    0.0000     0.000
# 4      4  58.000000  58.500000  56.062500  2650800.0    0.3818     0.000
#
#    Neutral  Positive  Label
# 0    0.805     0.195  False
# 1    1.000     0.000  False
# 2    0.678     0.000  False
# 3    1.000     0.000  False
# 4    0.658     0.342   True

# %%
new_hybrid.shape
# Out:
# (4476, 10)

# %% [markdown]
# ## Training and Testing the Models for Stock Price/Performance Analysis

# %%
X = new_hybrid.drop('Label', axis=1)    

y = new_hybrid['Label']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %%
np.any(np.isnan(x_train))
# Out:
# True

# %%
np.all(np.isfinite(x_train))
# Out:
# False

# %%
x_train = x_train.fillna(x_train.mean())

# %%
x_test=x_test.fillna(x_test.mean())

# %%
#plot_confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ## Stock Price/Performance analysis using Logistic Regressor Model

# %%
logit = LogisticRegression()
logit.fit(x_train,y_train)
y_logit_pred = logit.predict(x_test)
print(accuracy_score(y_test,y_logit_pred))
print(precision_score(y_test,y_logit_pred))
print(recall_score(y_test,y_logit_pred))
print(f1_score(y_test,y_logit_pred))
# Out:
# 0.8314732142857143
# 0.0
# 0.0
# 0.0

# %%
matrix_logit_cv=confusion_matrix(y_test,y_logit_pred)
print(matrix_logit_cv)
score_logit_cv=accuracy_score(y_test,y_logit_pred)
print(score_logit_cv)
report_logit_cv=classification_report(y_test,y_logit_pred)
print(report_logit_cv)
# Out:
# [[745   1]
#  [150   0]]
# 0.8314732142857143
#               precision    recall  f1-score   support
#
#        False       0.83      1.00      0.91       746
#         True       0.00      0.00      0.00       150
#
#     accuracy                           0.83       896
#    macro avg       0.42      0.50      0.45       896
# weighted avg       0.69      0.83      0.76       896

# %%
matrix = confusion_matrix(y_test, y_logit_pred)
print(matrix)
plot_confusion_matrix(matrix, classes=['Down', 'Up'])
# Out:
# [[745   1]
#  [150   0]]

# %% [markdown]
# ## Stock Price/Performance analysis using Random Forest Model

# %%
rf = RandomForestClassifier(n_estimators=200)
rf.fit(x_train,y_train)
y_rf_pred = rf.predict(x_test)
print(accuracy_score(y_test,y_rf_pred))
print(precision_score(y_test,y_rf_pred))
print(recall_score(y_test,y_rf_pred))
print(f1_score(y_test,y_rf_pred))
# Out:
# 0.8515625
# 0.6103896103896104
# 0.31333333333333335
# 0.41409691629955947

# %%
matrix_rf_cv=confusion_matrix(y_test,y_rf_pred)
print(matrix_rf_cv)
score_rf_cv=accuracy_score(y_test,y_rf_pred)
print(score_rf_cv)
report_rf_cv=classification_report(y_test,y_rf_pred)
print(report_rf_cv)
# Out:
# [[716  30]
#  [103  47]]
# 0.8515625
#               precision    recall  f1-score   support
#
#        False       0.87      0.96      0.92       746
#         True       0.61      0.31      0.41       150
#
#     accuracy                           0.85       896
#    macro avg       0.74      0.64      0.66       896
# weighted avg       0.83      0.85      0.83       896

# %%
matrix = confusion_matrix(y_test, y_rf_pred)
print(matrix)
plot_confusion_matrix(matrix, classes=['Down', 'Up'])
# Out:
# [[716  30]
#  [103  47]]

# %% [markdown]
# ## Stock Price/Performance analysis using Decision Tree Model

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
y_dt_pred = dt.predict(x_test)
print(accuracy_score(y_test,y_dt_pred))
print(precision_score(y_test,y_dt_pred))
print(recall_score(y_test,y_dt_pred))
print(f1_score(y_test,y_dt_pred))
# Out:
# 0.7756696428571429
# 0.3508771929824561
# 0.4
# 0.37383177570093457

# %%
matrix_dt_cv=confusion_matrix(y_test,y_dt_pred)
print(matrix_dt_cv)
score_dt_cv=accuracy_score(y_test,y_dt_pred)
print(score_dt_cv)
report_dt_cv=classification_report(y_test,y_dt_pred)
print(report_dt_cv)
# Out:
# [[635 111]
#  [ 90  60]]
# 0.7756696428571429
#               precision    recall  f1-score   support
#
#        False       0.88      0.85      0.86       746
#         True       0.35      0.40      0.37       150
#
#     accuracy                           0.78       896
#    macro avg       0.61      0.63      0.62       896
# weighted avg       0.79      0.78      0.78       896

# %%
matrix = confusion_matrix(y_test, y_dt_pred)
print(matrix)
plot_confusion_matrix(matrix, classes=['Down', 'Up'])
# Out:
# [[635 111]
#  [ 90  60]]

# %% [markdown]
# ## Stock Price/Performance analysis using Logistic Gradient Boosting Model

# %%
xgb = GradientBoostingClassifier()
xgb.fit(x_train, y_train)
y_xgb_pred = xgb.predict(x_test)
print(accuracy_score(y_test,y_xgb_pred))
print(precision_score(y_test,y_xgb_pred))
print(recall_score(y_test,y_xgb_pred))
print(f1_score(y_test,y_xgb_pred))
# Out:
# 0.8526785714285714
# 0.6607142857142857
# 0.24666666666666667
# 0.35922330097087374

# %%
matrix_xgb_cv=confusion_matrix(y_test,y_xgb_pred)
print(matrix_xgb_cv)
score_xgb_cv=accuracy_score(y_test,y_xgb_pred)
print(score_xgb_cv)
report_xgb_cv=classification_report(y_test,y_xgb_pred)
print(report_xgb_cv)
# Out:
# [[727  19]
#  [113  37]]
# 0.8526785714285714
#               precision    recall  f1-score   support
#
#        False       0.87      0.97      0.92       746
#         True       0.66      0.25      0.36       150
#
#     accuracy                           0.85       896
#    macro avg       0.76      0.61      0.64       896
# weighted avg       0.83      0.85      0.82       896

# %%
matrix = confusion_matrix(y_test, y_xgb_pred)
print(matrix)
plot_confusion_matrix(matrix, classes=['Down', 'Up'])
# Out:
# [[727  19]
#  [113  37]]

# %% [markdown]
# # Conclusion

# %%
print("Accuracy of Logistic Regression Model: ",accuracy_score(y_test,y_logit_pred)*100,"%")
print("Accuracy of Random forest Model      : ",accuracy_score(y_test,y_rf_pred)*100,"%")
print("Accuracy of Decision Tree Model      : ",accuracy_score(y_test,y_dt_pred)*100,"%")
print("Accuracy of Gradient Boosting Model  : ",accuracy_score(y_test,y_xgb_pred)*100,"%")
# Out:
# Accuracy of Logistic Regression Model:  83.14732142857143 %
# Accuracy of Random forest Model      :  85.15625 %
# Accuracy of Decision Tree Model      :  77.56696428571429 %
# Accuracy of Gradient Boosting Model  :  85.26785714285714 %
